# %% [markdown]
# Questa è una cella di documentazione in cui si può scrivere testo, formule latex tipo $\sqrt{81}=9$ e molto altro.
# Si scrive in questa cella in linguaggio Markdown. Nell'Help qua sopra sono presenti links a varie pagine di documentazione fra cui python, numpy, matplotlib e il linguaggio Markdown.
#
# La cella qua sotto è invece un esempio di codice python che usa la funzione sqrt() della libreria numpy.

# %%
import numpy as np
ncrcp= 81
print("Ma %d x %d farà %d?" % (np.sqrt(ncrcp), np.sqrt(ncrcp), ncrcp))
# Out:
# Ma 9 x 9 farà 81?

# %%
import matplotlib.pyplot as plt
x= np.arange(100)
y= np.sin(2*np.pi/100*x)
plt.plot(x, y, '-b.')
plt.legend(['sin(x)'])
plt.show()

# %% [markdown]
# Se qua sopra c'è il grafico di sen(x) allora la libreria matplotlib è correttamente installata.
